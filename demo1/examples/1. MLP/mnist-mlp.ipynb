# %%
# Nguyen Hai Duong
# nhduong_3010@live.com
# Chonnam National University
# 2018.01.21

# %% [markdown]
# # Overview
# - MNIST dataset
#   + Goal: recognizing handwritten digits
#   + Input: a 28x28 image
#   + Output: class label (0, 1,..., 9)
# - Defining an MLP for MNIST
# - Training and evaluating an MLP

# %% [markdown]
# # Import libraries

# %%
import keras
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, Flatten, Dense, Dropout
from keras.optimizers import SGD

from IPython.display import Image
from keras.utils import plot_model

import time
import numpy as np
import matplotlib.pyplot as plt

# %%
num_classes = 10   # 10 classes: 0, 1,..., 9

# %% [markdown]
# # (1) Data

# %%
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 28, 28)
x_test = x_test.reshape(10000, 28, 28)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # (2) Declare model

# %%
# 28x28 MNIST image
input_image = Input(shape=(28, 28), name='Input')

# matrix ---> vector
x = Flatten(name='flatten')(input_image)

# FC layers + dropout
x = Dense(units=512, activation='relu', name='fc1')(x)
x = Dropout(rate=0.2, name='dropout1')(x)

x = Dense(units=512, activation='relu', name='fc2')(x)
x = Dropout(rate=0.2, name='dropout2')(x)

output_label = Dense(units=num_classes, activation='softmax', name='fc3_10ways_softmax')(x)

# define model
model = Model(inputs=input_image, outputs=output_label, name='mnist_mlp')

# print model summary
model.summary()
# Out:
# Model: "mnist_mlp"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 28, 28)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 512)                 │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout1 (Dropout)                   │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc2 (Dense)                          │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout2 (Dropout)                   │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc3_10ways_softmax (Dense)           │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 669,706 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')

Image('model.png', width=400)

# %% [markdown]
# # (3) Train defined model
# - Note that the training history including loss and accuracy will be save in 'history' variable
# - In case your system runs out of memory (OOM), try to decrease batch size

# %%
# declare learning rate, loss function, and model metric
loss = 'categorical_crossentropy'
lr = 0.01

# Sửa lỗi ở đây: thay lr=lr bằng learning_rate=lr
model.compile(loss=loss, optimizer=SGD(learning_rate=lr), metrics=['accuracy'])

# train the model
batch_size = 128
epochs = 30

starting_time = time.time()
history = model.fit(x_train, y_train,
                    validation_data=(x_test, y_test),
                    batch_size=batch_size,
                    epochs=epochs)
print('> training time is %.4f minutes' % ((time.time() - starting_time)/60))
# Out:
# Epoch 1/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5123 - loss: 1.7163 - val_accuracy: 0.8732 - val_loss: 0.5390
# Epoch 2/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8410 - loss: 0.5800 - val_accuracy: 0.8986 - val_loss: 0.3748
# Epoch 3/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8730 - loss: 0.4417 - val_accuracy: 0.9124 - val_loss: 0.3208
# Epoch 4/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8907 - loss: 0.3764 - val_accuracy: 0.9184 - val_loss: 0.2918
# Epoch 5/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8989 - loss: 0.3469 - val_accuracy: 0.9244 - val_loss: 0.2708
# Epoch 6/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9073 - loss: 0.3205 - val_accuracy: 0.9280 - val_loss: 0.2538
# Epoch 7/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9088 - loss: 0.3120 - val_accuracy: 0.9311 - val_loss: 0.2407
# Epoch 8/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9169 - loss: 0.2857 - val_accuracy: 0.9356 - val_loss: 0.2297
# Epoch 9/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2750 - val_accuracy: 0.9384 - val_loss: 0.2188
# Epoch 10/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9237 - loss: 0.2597 - val_accuracy: 0.9394 - val_loss: 0.2081
# Epoch 11/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9287 - loss: 0.2502 - val_accuracy: 0.9422 - val_loss: 0.2002
# Epoch 12/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9310 - loss: 0.2326 - val_accuracy: 0.9453 - val_loss: 0.1911
# Epoch 13/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9355 - loss: 0.2254 - val_accuracy: 0.9466 - val_loss: 0.1844
# Epoch 14/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9397 - loss: 0.2136 - val_accuracy: 0.9485 - val_loss: 0.1767
# Epoch 15/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9403 - loss: 0.2070 - val_accuracy: 0.9500 - val_loss: 0.1702
# Epoch 16/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9414 - loss: 0.1996 - val_accuracy: 0.9516 - val_loss: 0.1650
# Epoch 17/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9440 - loss: 0.1934 - val_accuracy: 0.9527 - val_loss: 0.1592
# Epoch 18/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9476 - loss: 0.1830 - val_accuracy: 0.9533 - val_loss: 0.1551
# Epoch 19/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9473 - loss: 0.1805 - val_accuracy: 0.9556 - val_loss: 0.1496
# Epoch 20/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9490 - loss: 0.1772 - val_accuracy: 0.9570 - val_loss: 0.1449
# Epoch 21/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9507 - loss: 0.1678 - val_accuracy: 0.9578 - val_loss: 0.1417
# Epoch 22/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9527 - loss: 0.1618 - val_accuracy: 0.9595 - val_loss: 0.1378
# Epoch 23/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9551 - loss: 0.1583 - val_accuracy: 0.9604 - val_loss: 0.1352
# Epoch 24/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9514 - loss: 0.1615 - val_accuracy: 0.9596 - val_loss: 0.1326
# Epoch 25/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9552 - loss: 0.1496 - val_accuracy: 0.9614 - val_loss: 0.1283
# Epoch 26/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9574 - loss: 0.1479 - val_accuracy: 0.9624 - val_loss: 0.1249
# Epoch 27/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9581 - loss: 0.1423 - val_accuracy: 0.9628 - val_loss: 0.1228
# Epoch 28/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9580 - loss: 0.1408 - val_accuracy: 0.9624 - val_loss: 0.1204
# Epoch 29/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9592 - loss: 0.1407 - val_accuracy: 0.9637 - val_loss: 0.1183
# Epoch 30/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9610 - loss: 0.1325 - val_accuracy: 0.9649 - val_loss: 0.1159
# > training time is 0.5225 minutes

# %% [markdown]
# ### Training time
# - Training time with GTX 1080 is about 1.4402 minutes for 30 epochs
# - Training time with Core i7 is around 3.0493 minutes for 30 epochs

# %% [markdown]
# # (4) Evaluate trained model

# %%
score = model.evaluate(x_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9575 - loss: 0.1367
# Test loss: 0.11586444079875946
# Test accuracy: 0.964900016784668

# %%
# select a test image randomly
random_test_index = np.random.choice(x_test.shape[0], size=1)[0]
test_img = x_test[random_test_index]
test_label = np.argmax(y_test[random_test_index])

# predict test image with trained model
pred_label = model.predict(np.expand_dims(test_img, axis=0))
pred_label = np.argmax(pred_label)

plt.imshow(test_img, cmap='gray')
plt.title('true label = %d, predicted label = %d' % (test_label, pred_label))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
