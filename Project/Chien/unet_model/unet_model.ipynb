# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D,BatchNormalization,Cropping2D
from tensorflow.keras.models import Model
import random
import tensorflow as tf

# %%
# Đọc tệp Excel vào DataFrame
file_path = "C:/Users/thres/Downloads/data/classification.xlsx"  # Đường dẫn đến file Excel
df = pd.read_excel(file_path)

# Đường dẫn thư mục ảnh và mask
image_path = 'C:/Users/thres/Downloads/data/images'
mask_path = 'C:/Users/thres/Downloads/data/masks'
print("dfasdfd")
# Out:
# dfasdfd

# %%
# Lọc những ảnh có mask
df_with_mask = df[df['mask_flag'] == 1]

# Chia train, test, valid
df_train = df_with_mask[df_with_mask['tumor_category'] == 1].copy()
df_test  = df_with_mask[df_with_mask['tumor_category'] == 2].copy()
df_valid = df_with_mask[df_with_mask['tumor_category'] == 3].copy()
print("dfasdfd")
# Out:
# dfasdfd

# %%
# Tạo cột đường dẫn
df_train['image_path'] = df_train['image_id'].apply(lambda x: os.path.join(image_path, f"{os.path.splitext(x)[0]}.jpg"))
df_train['mask_path']  = df_train['image_id'].apply(lambda x: os.path.join(mask_path, f"{os.path.splitext(x)[0]}.png"))

df_test['image_path'] = df_test['image_id'].apply(lambda x: os.path.join(image_path, f"{os.path.splitext(x)[0]}.jpg"))
df_test['mask_path']  = df_test['image_id'].apply(lambda x: os.path.join(mask_path, f"{os.path.splitext(x)[0]}.png"))

df_valid['image_path'] = df_valid['image_id'].apply(lambda x: os.path.join(image_path, f"{os.path.splitext(x)[0]}.jpg"))
df_valid['mask_path']  = df_valid['image_id'].apply(lambda x: os.path.join(mask_path, f"{os.path.splitext(x)[0]}.png"))

print("dfasdfd")
# Out:
# dfasdfd

# %%
# Hàm load ảnh và mask
def load_image_and_mask(image_path, mask_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=1)
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.convert_image_dtype(mask, tf.float32)
    
    image = tf.image.resize(image, (224, 224))
    mask = tf.image.resize(mask, (224, 224))
    return image, mask

# Chọn batch size random trước
BATCH_SIZE = random.choice([8, 16, 32, 64])

# Tạo datasets
train_dataset = tf.data.Dataset.from_tensor_slices((df_train['image_path'], df_train['mask_path']))
train_dataset = train_dataset.map(load_image_and_mask)
train_dataset = train_dataset.shuffle(buffer_size=1000)
train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((df_valid['image_path'], df_valid['mask_path']))
val_dataset = val_dataset.map(load_image_and_mask)
val_dataset = val_dataset.batch(16).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((df_test['image_path'], df_test['mask_path']))
test_dataset = test_dataset.map(load_image_and_mask)
test_dataset = test_dataset.batch(16).prefetch(tf.data.AUTOTUNE)
print("dfasdfd")
# Out:
# dfasdfd

# %%
import matplotlib.pyplot as plt

# Kiểm tra một batch từ train_dataset
for images, masks in train_dataset.take(1):  # Lấy 1 batch từ train_dataset
    print("Train batch shape:")
    print("Image batch shape:", images.shape)  # Kích thước của batch ảnh
    print("Mask batch shape:", masks.shape)    # Kích thước của batch mask

    # Hiển thị một ảnh và mask
    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.imshow(images[0, :, :, 0], cmap='gray')  # Hiển thị ảnh đầu tiên trong batch (1 channel)
    plt.title("Sample Input Image")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(masks[0, :, :, 0], cmap='gray')  # Hiển thị mask đầu tiên trong batch (1 channel)
    plt.title("Sample Mask")
    plt.axis('off')

    plt.show()
    break  # Dừng sau khi đã kiểm tra 1 batch

# Kiểm tra một batch từ val_dataset
for images, masks in val_dataset.take(1):
    print("Validation batch shape:")
    print("Image batch shape:", images.shape)
    print("Mask batch shape:", masks.shape)

    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.imshow(images[0, :, :, 0], cmap='gray')
    plt.title("Sample Input Image (Validation)")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(masks[0, :, :, 0], cmap='gray')
    plt.title("Sample Mask (Validation)")
    plt.axis('off')

    plt.show()
    break

# Kiểm tra một batch từ test_dataset
for images, masks in test_dataset.take(1):
    print("Test batch shape:")
    print("Image batch shape:", images.shape)
    print("Mask batch shape:", masks.shape)

    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.imshow(images[0, :, :, 0], cmap='gray')
    plt.title("Sample Input Image (Test)")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(masks[0, :, :, 0], cmap='gray')
    plt.title("Sample Mask (Test)")
    plt.axis('off')

    plt.show()
    break
print("dfasdfd")
# Out:
# Train batch shape:
# Image batch shape: (8, 224, 224, 1)
# Mask batch shape: (8, 224, 224, 1)
# Validation batch shape:
# Image batch shape: (16, 224, 224, 1)
# Mask batch shape: (16, 224, 224, 1)
# Test batch shape:
# Image batch shape: (16, 224, 224, 1)
# Mask batch shape: (16, 224, 224, 1)
# dfasdfd

# %%
# Hàm 2 lớp conv + batchnorm + relu
def conv_block(x, filters):
    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    return x

# Khối Attention
def attention_block(x, g, filters):
    theta_x = layers.Conv2D(filters, (1, 1))(x)
    phi_g = layers.Conv2D(filters, (1, 1))(g)

    add = layers.Add()([theta_x, phi_g])
    act = layers.Activation('relu')(add)
    psi = layers.Conv2D(1, (1, 1))(act)
    psi = layers.Activation('sigmoid')(psi)

    att = layers.Multiply()([x, psi])
    return att

# Khối encoder: conv -> dropout -> pooling
def encoder_block(x, filters, dropout_rate=0.3):
    conv = conv_block(x, filters)
    conv = layers.Dropout(dropout_rate)(conv)
    pool = layers.MaxPooling2D((2, 2))(conv)
    return conv, pool

# Khối decoder: upsampling -> attention -> concat -> conv
def decoder_block(x, skip, filters):
    up = layers.UpSampling2D((2, 2))(x)
    up = layers.Conv2D(filters, (2, 2), activation='relu', padding='same')(up)

    attn = attention_block(skip, up, filters)

    merge = layers.concatenate([up, attn])
    conv = conv_block(merge, filters)
    return conv

# Xây dựng mô hình UNet + Attention
def unet_attention(input_shape=(224, 224, 1), num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    # Bottleneck
    b1 = conv_block(p4, 1024)
    b1 = layers.Dropout(0.3)(b1)
    b1 = conv_block(b1, 1024)
    b1 = layers.Dropout(0.3)(b1)

    # Decoder
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    # Output layer
    if num_classes == 1:
        activation = 'sigmoid'
    else:
        activation = 'softmax'

    outputs = layers.Conv2D(num_classes, (1, 1), activation=activation)(d4)

    model = models.Model(inputs, outputs)
    return model

# Khởi tạo mô hình
model = unet_attention(input_shape=(224, 224, 1), num_classes=1)

# Compile
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.MeanIoU(num_classes=2)
    ]
)

# Summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 224, 224,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 224, 224,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 224, 224,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 224, 224,  │          0 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ dropout[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 112, 112,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 112, 112,  │          0 │ activation_3[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 56, 56,    │          0 │ dropout_1[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 56, 56,    │          0 │ activation_5[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ dropout_2[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 28, 28,    │          0 │ activation_7[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 14, 14,    │          0 │ dropout_3[0][0]   │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 14, 14,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 14, 14,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 14, 14,    │          0 │ activation_9[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 14, 14,    │  9,438,208 │ dropout_4[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      4,096 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 14, 14,    │  9,438,208 │ activation_10[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      4,096 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 14, 14,    │          0 │ activation_11[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 28, 28,    │          0 │ dropout_5[0][0]   │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 28, 28,    │  2,097,664 │ up_sampling2d[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 28, 28,    │    262,656 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 28, 28,    │    262,656 │ conv2d_12[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 28, 28,    │          0 │ conv2d_13[0][0],  │
# │                     │ 512)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 28, 28,    │          0 │ add[0][0]         │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 28, 28, 1) │        513 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 28, 28, 1) │          0 │ conv2d_15[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 28, 28,    │          0 │ dropout_3[0][0],  │
# │                     │ 512)              │            │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 28, 28,    │          0 │ conv2d_12[0][0],  │
# │ (Concatenate)       │ 1024)             │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 28, 28,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      2,048 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 28, 28,    │  2,359,808 │ activation_14[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      2,048 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 56, 56,    │          0 │ activation_15[0]… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 56, 56,    │    524,544 │ up_sampling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 56, 56,    │     65,792 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 56, 56,    │     65,792 │ conv2d_18[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 56, 56,    │          0 │ conv2d_19[0][0],  │
# │                     │ 256)              │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 56, 56,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 56, 56, 1) │        257 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 56, 56, 1) │          0 │ conv2d_21[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 56, 56,    │          0 │ dropout_2[0][0],  │
# │ (Multiply)          │ 256)              │            │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 56, 56,    │          0 │ conv2d_18[0][0],  │
# │ (Concatenate)       │ 512)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 56, 56,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │      1,024 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 56, 56,    │    590,080 │ activation_18[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 112, 112,  │          0 │ activation_19[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 112, 112,  │    131,200 │ up_sampling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 112, 112,  │     16,512 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 112, 112,  │     16,512 │ conv2d_24[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 112, 112,  │          0 │ conv2d_25[0][0],  │
# │                     │ 128)              │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 112, 112,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 112, 112,  │        129 │ activation_20[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 112, 112,  │          0 │ conv2d_27[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 112, 112,  │          0 │ dropout_1[0][0],  │
# │ (Multiply)          │ 128)              │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 112, 112,  │          0 │ conv2d_24[0][0],  │
# │ (Concatenate)       │ 256)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 112, 112,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        512 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 112, 112,  │    147,584 │ activation_22[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        512 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 224, 224,  │          0 │ activation_23[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 224, 224,  │     32,832 │ up_sampling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 224, 224,  │      4,160 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 224, 224,  │      4,160 │ conv2d_30[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 224, 224,  │          0 │ conv2d_31[0][0],  │
# │                     │ 64)               │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 224, 224,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 224, 224,  │         65 │ activation_24[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 224, 224,  │          0 │ conv2d_33[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 224, 224,  │          0 │ dropout[0][0],    │
# │ (Multiply)          │ 64)               │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 224, 224,  │          0 │ conv2d_30[0][0],  │
# │ (Concatenate)       │ 128)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 224, 224,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 224, 224,  │        256 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 224, 224,  │     36,928 │ activation_26[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 224, 224,  │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 224, 224,  │         65 │ activation_27[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 50,637,957 (193.17 MB)
#  Trainable params: 50,622,085 (193.11 MB)
#  Non-trainable params: 15,872 (62.00 KB)

# %%
# === Huấn luyện mô hình ===
epochs = 50  # Đặt số epoch là 50, nhưng sẽ dừng sớm nếu có điều kiện dừng sớm từ callback khác

history = model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=val_dataset,
    verbose=1
)

print("✅ Quá trình huấn luyện hoàn tất!")
# Out:
# Epoch 1/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 944s 6s/step - accuracy: 0.9543 - loss: 0.1791 - mean_io_u: 0.4912 - precision: 0.0144 - recall: 0.0241 - val_accuracy: 0.9824 - val_loss: 0.1589 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 934s 6s/step - accuracy: 0.9829 - loss: 0.0713 - mean_io_u: 0.4915 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.1117 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 933s 6s/step - accuracy: 0.9819 - loss: 0.0706 - mean_io_u: 0.4909 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0848 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 939s 6s/step - accuracy: 0.9832 - loss: 0.0668 - mean_io_u: 0.4916 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.1165 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 941s 6s/step - accuracy: 0.9815 - loss: 0.0691 - mean_io_u: 0.4907 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0700 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 943s 6s/step - accuracy: 0.9828 - loss: 0.0654 - mean_io_u: 0.4914 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0709 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 943s 6s/step - accuracy: 0.9818 - loss: 0.0671 - mean_io_u: 0.4909 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0974 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 942s 6s/step - accuracy: 0.9816 - loss: 0.0664 - mean_io_u: 0.4908 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.1471 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 942s 6s/step - accuracy: 0.9819 - loss: 0.0674 - mean_io_u: 0.4909 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0966 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 943s 6s/step - accuracy: 0.9825 - loss: 0.0645 - mean_io_u: 0.4912 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0805 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 942s 6s/step - accuracy: 0.9821 - loss: 0.0643 - mean_io_u: 0.4911 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0698 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 942s 6s/step - accuracy: 0.9819 - loss: 0.0660 - mean_io_u: 0.4910 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0828 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 938s 6s/step - accuracy: 0.9829 - loss: 0.0613 - mean_io_u: 0.4914 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0706 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 939s 6s/step - accuracy: 0.9811 - loss: 0.0663 - mean_io_u: 0.4906 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0736 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 939s 6s/step - accuracy: 0.9818 - loss: 0.0640 - mean_io_u: 0.4909 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0715 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 981s 6s/step - accuracy: 0.9827 - loss: 0.0619 - mean_io_u: 0.4914 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0683 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 958s 6s/step - accuracy: 0.9815 - loss: 0.0635 - mean_io_u: 0.4908 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0695 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 953s 6s/step - accuracy: 0.9832 - loss: 0.0591 - mean_io_u: 0.4916 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0708 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 946s 6s/step - accuracy: 0.9816 - loss: 0.0640 - mean_io_u: 0.4908 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0709 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 946s 6s/step - accuracy: 0.9818 - loss: 0.0618 - mean_io_u: 0.4909 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0704 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 940s 6s/step - accuracy: 0.9823 - loss: 0.0599 - mean_io_u: 0.4912 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0681 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 937s 6s/step - accuracy: 0.9821 - loss: 0.0623 - mean_io_u: 0.4910 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0955 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 936s 6s/step - accuracy: 0.9822 - loss: 0.0609 - mean_io_u: 0.4911 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0694 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 937s 6s/step - accuracy: 0.9817 - loss: 0.0610 - mean_io_u: 0.4908 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0761 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 935s 6s/step - accuracy: 0.9833 - loss: 0.0562 - mean_io_u: 0.4917 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0726 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 934s 6s/step - accuracy: 0.9831 - loss: 0.0585 - mean_io_u: 0.4916 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0663 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 936s 6s/step - accuracy: 0.9816 - loss: 0.0594 - mean_io_u: 0.4908 - precision: 0.3467 - recall: 1.9707e-04 - val_accuracy: 0.9824 - val_loss: 0.0706 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 936s 6s/step - accuracy: 0.9815 - loss: 0.0596 - mean_io_u: 0.4908 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0714 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 935s 6s/step - accuracy: 0.9811 - loss: 0.0600 - mean_io_u: 0.4906 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9824 - val_loss: 0.0779 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 934s 6s/step - accuracy: 0.9819 - loss: 0.0580 - mean_io_u: 0.4910 - precision: 0.2082 - recall: 0.0026 - val_accuracy: 0.9824 - val_loss: 0.0753 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 935s 6s/step - accuracy: 0.9824 - loss: 0.0534 - mean_io_u: 0.4912 - precision: 0.3023 - recall: 0.0050 - val_accuracy: 0.9824 - val_loss: 0.0651 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 939s 6s/step - accuracy: 0.9822 - loss: 0.0548 - mean_io_u: 0.4910 - precision: 0.4986 - recall: 0.0276 - val_accuracy: 0.9824 - val_loss: 0.0777 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 936s 6s/step - accuracy: 0.9824 - loss: 0.0544 - mean_io_u: 0.4911 - precision: 0.5753 - recall: 0.0711 - val_accuracy: 0.9824 - val_loss: 0.0719 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 938s 6s/step - accuracy: 0.9835 - loss: 0.0511 - mean_io_u: 0.4914 - precision: 0.5951 - recall: 0.1249 - val_accuracy: 0.9823 - val_loss: 0.0641 - val_mean_io_u: 0.4912 - val_precision: 0.4606 - val_recall: 0.0476
# Epoch 35/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 938s 6s/step - accuracy: 0.9829 - loss: 0.0531 - mean_io_u: 0.4908 - precision: 0.6325 - recall: 0.1565 - val_accuracy: 0.9824 - val_loss: 0.0752 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 938s 6s/step - accuracy: 0.9840 - loss: 0.0486 - mean_io_u: 0.4915 - precision: 0.6099 - recall: 0.1745 - val_accuracy: 0.9824 - val_loss: 0.0854 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 936s 6s/step - accuracy: 0.9831 - loss: 0.0519 - mean_io_u: 0.4908 - precision: 0.6275 - recall: 0.2146 - val_accuracy: 0.9762 - val_loss: 0.0686 - val_mean_io_u: 0.4912 - val_precision: 0.2785 - val_recall: 0.2207
# Epoch 38/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 935s 6s/step - accuracy: 0.9836 - loss: 0.0483 - mean_io_u: 0.4906 - precision: 0.6684 - recall: 0.2468 - val_accuracy: 0.9824 - val_loss: 0.0828 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 935s 6s/step - accuracy: 0.9829 - loss: 0.0502 - mean_io_u: 0.4904 - precision: 0.6690 - recall: 0.2266 - val_accuracy: 0.9825 - val_loss: 0.0725 - val_mean_io_u: 0.4912 - val_precision: 0.9976 - val_recall: 0.0027
# Epoch 40/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 931s 6s/step - accuracy: 0.9841 - loss: 0.0459 - mean_io_u: 0.4909 - precision: 0.6469 - recall: 0.2855 - val_accuracy: 0.9824 - val_loss: 0.0725 - val_mean_io_u: 0.4912 - val_precision: 0.4777 - val_recall: 0.0134
# Epoch 41/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 931s 6s/step - accuracy: 0.9847 - loss: 0.0438 - mean_io_u: 0.4911 - precision: 0.6556 - recall: 0.3032 - val_accuracy: 0.9825 - val_loss: 0.0783 - val_mean_io_u: 0.4912 - val_precision: 0.6446 - val_recall: 0.0088
# Epoch 42/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 933s 6s/step - accuracy: 0.9837 - loss: 0.0461 - mean_io_u: 0.4900 - precision: 0.6984 - recall: 0.3308 - val_accuracy: 0.9824 - val_loss: 0.0660 - val_mean_io_u: 0.4912 - val_precision: 0.4966 - val_recall: 0.0387
# Epoch 43/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 933s 6s/step - accuracy: 0.9856 - loss: 0.0410 - mean_io_u: 0.4913 - precision: 0.6641 - recall: 0.3524 - val_accuracy: 0.9827 - val_loss: 0.0754 - val_mean_io_u: 0.4912 - val_precision: 0.8970 - val_recall: 0.0153
# Epoch 44/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 933s 6s/step - accuracy: 0.9860 - loss: 0.0400 - mean_io_u: 0.4910 - precision: 0.7069 - recall: 0.3890 - val_accuracy: 0.9824 - val_loss: 0.0981 - val_mean_io_u: 0.4912 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 933s 6s/step - accuracy: 0.9860 - loss: 0.0402 - mean_io_u: 0.4909 - precision: 0.7124 - recall: 0.3881 - val_accuracy: 0.9825 - val_loss: 0.0869 - val_mean_io_u: 0.4912 - val_precision: 0.8680 - val_recall: 0.0066
# Epoch 46/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 936s 6s/step - accuracy: 0.9875 - loss: 0.0362 - mean_io_u: 0.4914 - precision: 0.7178 - recall: 0.4566 - val_accuracy: 0.9826 - val_loss: 0.0737 - val_mean_io_u: 0.4912 - val_precision: 0.5844 - val_recall: 0.0321
# Epoch 47/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 934s 6s/step - accuracy: 0.9875 - loss: 0.0353 - mean_io_u: 0.4914 - precision: 0.7146 - recall: 0.4653 - val_accuracy: 0.9824 - val_loss: 0.0971 - val_mean_io_u: 0.4912 - val_precision: 0.9079 - val_recall: 0.0014
# Epoch 48/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 934s 6s/step - accuracy: 0.9878 - loss: 0.0339 - mean_io_u: 0.4912 - precision: 0.7298 - recall: 0.4885 - val_accuracy: 0.9825 - val_loss: 0.0966 - val_mean_io_u: 0.4912 - val_precision: 1.0000 - val_recall: 0.0025
# Epoch 49/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 938s 6s/step - accuracy: 0.9886 - loss: 0.0315 - mean_io_u: 0.4916 - precision: 0.7354 - recall: 0.5068 - val_accuracy: 0.9828 - val_loss: 0.0816 - val_mean_io_u: 0.4912 - val_precision: 0.7814 - val_recall: 0.0299
# Epoch 50/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 942s 6s/step - accuracy: 0.9886 - loss: 0.0317 - mean_io_u: 0.4908 - precision: 0.7656 - recall: 0.5426 - val_accuracy: 0.9827 - val_loss: 0.1038 - val_mean_io_u: 0.4912 - val_precision: 0.7512 - val_recall: 0.0213
# ✅ Quá trình huấn luyện hoàn tất!

# %%
results = model.evaluate(test_dataset)
print(f"Results: {results}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9822 - loss: 0.0976 - mean_io_u: 0.4909 - precision: 0.7946 - recall: 0.0337
# Results: [0.0974079892039299, 0.9829186797142029, 0.8484972715377808, 0.025204451754689217, 0.4912787973880768]

# %%
# Dự đoán trên test dataset và hiển thị kết quả
for image_batch, mask_batch in test_dataset.take(1):  # Chỉ lấy một batch từ test dataset
    pred_batch = model.predict(image_batch)  # Dự đoán cho batch
    pred_batch = (pred_batch > 0.5).astype(np.float32)  # Chuyển sang nhị phân (0 hoặc 1)

    # Hiển thị ảnh gốc, mask thực tế và mask dự đoán
    plt.figure(figsize=(12, 12))
    for i in range(min(4, len(image_batch))):  # Chỉ hiển thị 4 ảnh đầu tiên
        # Ảnh gốc
        plt.subplot(4, 3, i * 3 + 1)
        plt.imshow(image_batch[i, :, :, 0], cmap='gray')
        plt.title("Image")
        plt.axis('off')

        # Mask thực tế
        plt.subplot(4, 3, i * 3 + 2)
        plt.imshow(mask_batch[i, :, :, 0], cmap='gray')
        plt.title("True Mask")
        plt.axis('off')

        # Mask dự đoán
        plt.subplot(4, 3, i * 3 + 3)
        plt.imshow(pred_batch[i, :, :, 0], cmap='gray')
        plt.title("Predicted Mask")
        plt.axis('off')

    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
model.save('unet_model.h5')  # Lưu mô hình dưới dạng file .h5
model.save('D:/NCKH/Project/Chien/unet_model.h5')  # Lưu mô hình vào thư mục /kaggle/working
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
